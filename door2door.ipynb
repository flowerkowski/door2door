# %% [markdown]
# | Developer         | Version | Task (JIRA number) |
# |--------------|:-----:|-----------:|
# | Dejan Cvetkovski |  1.00 |        LOKA-Interview-1 |

# %% [markdown]
# These widgets will be used as parameters in the Workflow to run this notebook daily and load new files.
#
# You can specify the process date, the S3 bucket location or the type of files you want to load (JSON by default).

# %%
dbutils.widgets.text("file_location", "s3://de-tech-assessment-2022/data", "Upload Location")
dbutils.widgets.dropdown("file_type", "json", ["csv", 'parquet', 'json'])
dbutils.widgets.text("process_date", "2019-06-01", "Process Date")

# %% [markdown]
# This part will be in the Workflow (Databricks Job) to calculate the day before today and run the job with passing this to the job as paramter.
#
# For the purpose of this excercise we hardcoded the date to 2019-06-10 the only day the S3 bucket has files for.

# %%
from pyspark.sql.functions import current_date

yesterday = spark.sql("SELECT current_date()-1").collect()[0][0]
print(yesterday)
process_date = dbutils.widgets.get("process_date")
print(process_date)
# Out:
# 2023-02-21
# 2019-06-01

# %%
df_bronze = spark.read.format(dbutils.widgets.get("file_type")).option("inferSchema", "true").load(dbutils.widgets.get("file_location"))

# %%
df_bronze.count()
# Out:
# Out[16]: 35351

# %%
display(df_bronze)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>at</th><th>data</th><th>event</th><th>on</th><th>organization_id</th></tr></thead><tbody><tr><td>2019-06-01T18:17:18.122Z</td><td>List(null, bac5188f-67c6-4965-81dc-4ef49622e280, List(2019-06-01T18:17:18.122Z, 52.45246, 13.45908), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.130Z</td><td>List(null, 3a3eb23a-f22e-4fe9-8c20-f37220a81909, List(2019-06-01T18:17:18.130Z, 52.46068, 13.52142), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, f06eb89c-ada0-41cb-bdd1-0a60398f901b, List(2019-06-01T18:17:18.131Z, 52.49762, 13.44824), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.130Z</td><td>List(null, f0b87796-b25c-40b0-9145-8822509c17e1, List(2019-06-01T18:17:18.130Z, 52.50432, 13.33656), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, e641b45f-f007-4d7a-af94-b81b8a05a325, List(2019-06-01T18:17:18.131Z, 52.49196, 13.26401), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.130Z</td><td>List(null, 9152c5d8-79cf-4fe3-96ad-359abb08a729, List(2019-06-01T18:17:18.130Z, 52.50558, 13.51499), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, 949798fc-50aa-47a4-a7e0-db418eee2ab6, List(2019-06-01T18:17:18.131Z, 52.54977, 13.5087), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, 9d6a8840-def2-42b6-af24-f19a3c6de059, List(2019-06-01T18:17:18.131Z, 52.46555, 13.33878), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, 3b0640d6-502d-4623-b782-39cc789b4e8d, List(2019-06-01T18:17:18.131Z, 52.57723, 13.26686), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, 98c8b8cb-7c2b-415d-ad30-fa9f0571a5f5, List(2019-06-01T18:17:18.131Z, 52.50497, 13.25367), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, d6880741-ae7f-4741-aa04-950b0a1e2d3b, List(2019-06-01T18:17:18.131Z, 52.47863, 13.31848), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, d759fc35-b25c-4877-8e40-9b0104447b31, List(2019-06-01T18:17:18.131Z, 52.45261, 13.46194), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, 49c02de6-2bc6-46ca-9e55-8eb656a90965, List(2019-06-01T18:17:18.131Z, 52.44506, 13.24246), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, b4dac3b4-0142-4319-bce2-1324760294b5, List(2019-06-01T18:17:18.131Z, 52.47347, 13.54482), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>List(null, 46952066-0a94-4a2a-9c31-08c93f8ea3f1, List(2019-06-01T18:17:18.131Z, 52.49426, 13.26689), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.140Z</td><td>List(null, ae413d00-fb27-4761-8655-4b8c0fff4a8e, List(2019-06-01T18:17:18.140Z, 52.45681, 13.47635), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.140Z</td><td>List(null, a38edd77-07b0-4069-8a1d-462428989ecf, List(2019-06-01T18:17:18.140Z, 52.44506, 13.24246), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.140Z</td><td>List(null, 804ac7f0-cf1d-4b29-9ed2-9bebecf76005, List(2019-06-01T18:17:18.140Z, 52.43972, 13.50736), null)</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.140Z</td><td>List(null, 46f718d4-50de-4684-bf36-63135a3e2dc0, List(2019-06-01T18:17:18.140Z, 52.47297, 13.45835 ...

# %%
df_bronze.write.format("delta").saveAsTable("door2door_table_bronze")

# %%
from pyspark.sql.functions import from_utc_timestamp, date_format

# Assume the DataFrame is called `df` and the column is called `utc_date`
df_bronze = df_bronze.withColumn("date_only", date_format(from_utc_timestamp("at", "UTC"), "yyyy-MM-dd"))

# Show the results
df_bronze.show()
# Out:
# +--------------------+--------------------+------+-------+---------------+----------+
# |                  at|                data| event|     on|organization_id| date_only|
# +--------------------+--------------------+------+-------+---------------+----------+
# |2019-06-01T18:17:...|{null, bac5188f-6...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 3a3eb23a-f...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, f06eb89c-a...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, f0b87796-b...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, e641b45f-f...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 9152c5d8-7...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 949798fc-5...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 9d6a8840-d...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 3b0640d6-5...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 98c8b8cb-7...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, d6880741-a...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, d759fc35-b...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 49c02de6-2...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, b4dac3b4-0...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 46952066-0...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, ae413d00-f...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, a38edd77-0...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 804ac7f0-c...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 46f718d4-5...|update|vehicle|         org-id|2019-06-01|
# |2019-06-01T18:17:...|{null, 8efb00c5-3...|update|vehicle|         org-id|2019-06-01|
# +--------------------+--------------------+------+-------+---------------+----------+
# only showing top 20 rows

# %% [markdown]
# In the cell below we flatten the nested JSON and pick only the current date we want to process and merge in the final data

# %%
from pyspark.sql.functions import *

df_silver = df_bronze.select("at", "data.id", "data.start", "data.finish", "data.location.lat", "data.location.lng", "event", "on", "organization_id").filter(col("date_only") == process_date)

# %%
display(df_silver)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>at</th><th>id</th><th>start</th><th>finish</th><th>lat</th><th>lng</th><th>event</th><th>on</th><th>organization_id</th></tr></thead><tbody><tr><td>2019-06-01T18:17:18.122Z</td><td>bac5188f-67c6-4965-81dc-4ef49622e280</td><td>null</td><td>null</td><td>52.45246</td><td>13.45908</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.130Z</td><td>3a3eb23a-f22e-4fe9-8c20-f37220a81909</td><td>null</td><td>null</td><td>52.46068</td><td>13.52142</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>f06eb89c-ada0-41cb-bdd1-0a60398f901b</td><td>null</td><td>null</td><td>52.49762</td><td>13.44824</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.130Z</td><td>f0b87796-b25c-40b0-9145-8822509c17e1</td><td>null</td><td>null</td><td>52.50432</td><td>13.33656</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18.131Z</td><td>e641b45f-f007-4d7a-af94-b81b8a05a325</td><td>null</td><td>null</td><td>52.49196</td><td>13.26401</td><td>update</td><td>vehicle</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:18

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>at</th><th>id</th><th>start</th><th>finish</th><th>lat</th><th>lng</th><th>event</th><th>on</th><th>organization_id</th></tr></thead><tbody><tr><td>2019-06-01T18:17:03.087Z</td><td>op_2</td><td>2019-06-01T18:17:04.079Z</td><td>2019-06-01T18:22:04.079Z</td><td>null</td><td>null</td><td>create</td><td>operating_period</td><td>org-id</td></tr><tr><td>2019-06-01T18:17:04.086Z</td><td>op_1</td><td>2019-06-01T18:23:04.079Z</td><td>2019-06-01T18:28:04.079Z</td><td>null</td><td>null</td><td>create</td><td>operating_period</td><td>org-id</td></tr></tbody></table></div>

# %%
# %sql

CREATE TABLE operating_period AS
SELECT at, id, start, finish, event 
FROM door2door_table_silver
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql

CREATE TABLE vehicle AS
SELECT at, id, lat, lng, event 
FROM door2door_table_silver
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
df_operating_period = spark.sql("SELECT * from operating_period")
df_vehicle = spark.sql("SELECT * from vehicle")

# %%
from pyspark.sql.functions import *

# Create a temporary view for the new data
df_vehicle.createOrReplaceTempView("tmp_vehicle")

# Merge the new data with the Delta table using the join condition
merged_data = (spark.table("vehicle").alias("target")
               .join(spark.table("tmp_vehicle").alias("source"), ["at", "id"], "outer")
               .selectExpr("source.*")
               .where(col("target.id").isNull() & col("target.at").isNull())
              )

# Append the new rows to the Delta table
merged_data.write.format("delta").mode("append").saveAsTable("vehicle")

df_operating_period.createOrReplaceTempView("tmp_operating_period")

# Merge the new data with the Delta table using the join condition
merged_data = (spark.table("operating_period").alias("target")
               .join(spark.table("tmp_operating_period").alias("source"), ["at", "id"], "outer")
               .selectExpr("source.*")
               .where(col("target.id").isNull() & col("target.at").isNull())
              )

# Append the new rows to the Delta table
merged_data.write.format("delta").mode("append").saveAsTable("operating_period")

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

vehicle_df = spark.sql("SELECT * from vehicle")

windowSpec = Window.partitionBy("id").orderBy("at")

vehicleWithRowNum = vehicle_df.withColumn("row_num", row_number().over(windowSpec))

# Show the new DataFrame with row numbers
vehicleWithRowNum.show()
# Out:
# +--------------------+--------------------+--------+--------+--------+-------+
# |                  at|                  id|     lat|     lng|   event|row_num|
# +--------------------+--------------------+--------+--------+--------+-------+
# |2019-06-01T18:17:...|0317b799-8d70-482...|    null|    null|register|      1|
# |2019-06-01T18:17:...|0317b799-8d70-482...| 52.5266|13.48931|  update|      2|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52661|13.48892|  update|      3|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52661|13.48878|  update|      4|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52662|13.48846|  update|      5|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52662|13.48801|  update|      6|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52664|13.48725|  update|      7|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52665|13.48687|  update|      8|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52665|13.48674|  update|      9|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52666|13.48662|  update|     10|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52668|13.48557|  update|     11|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52668|13.48534|  update|     12|
# |2019-06-01T18:17:...|0317b799-8d70-482...| 52.5267|13.48444|  update|     13|
# |2019-06-01T18:17:...|0317b799-8d70-482...| 52.5267|13.48438|  update|     14|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52674|13.48285|  update|     15|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52676|  13.482|  update|     16|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52676|13.48181|  update|     17|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52677|13.48109|  update|     18|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52671|13.48057|  update|     19|
# |2019-06-01T18:17:...|0317b799-8d70-482...|52.52667|13.48018|  update|     20|
# +--------------------+--------------------+--------+--------+--------+-------+
# only showing top 20 rows
